# %% [markdown]
# # Revisão de Python
#
# ## Conceitos Fundamentais

# %% [markdown]
# ### Literais em Python

# %%
from operator import truediv

texto:str # Literal do tipo texto, conhecido como string. Exemplo: "Senai", "SENAI"...
inteiro:int # Literal do tipo números inteiros. Exemplos: 1, 2, 3, 4, -1, -10...
reais:float # Literal do tipo números de ponto flutuante. Exemplos: 1.73, 2.56, -1.41...
booleanos:bool # Literal do tipo booleano, só aceita dois tipos de valores: VERDADEIRO (True) ou FALSO (False)

# %%
texto = "Clodoaldo"
inteiro = 10
reais = 1.73
booleanos = False

# %% [markdown]
# ### Saída de dados
#
# Interpolação, concatenação, entre outros.

# %%
print(texto)
# Out:
# Clodoaldo

# %%
print(f"O dado que está guardado dentro da variável texto é {texto}")
# Out:
# O dado que está guardado dentro da variável texto é Clodoaldo

# %%
print("Senai" + "Americana") # Concatenação
# Out:
# SenaiAmericana

# %%
print("Senai", end=';')
print(texto)

# %%
print("Senai", sep=" ")
print("Senai")

# %% [markdown]
# ### Processamento de Dados
#
# Operações aritméticas, comparação e lógicas

# %% [markdown]
# #### Operadores aritméticos
#
# soma, subtração, multiplicação, divisão...

# %%
a = 1
b = 2

# %%
resultado = a + b # Soma
print(resultado)
resultado = a - b # Subtração
print(resultado)
resultado = a * b # Multiplicação
print(resultado)
resultado = a / b # Divisão
print(resultado)
resultado = a % b # Resto de divisão
print(resultado)
resultado = a // b # Divisão inteira
print(resultado)
resultado = a ** b # Potência
print(resultado)

# %% [markdown]
# #### Operações de comparação

# %%
resultado = a > b
print(resultado)
resultado = a < b
print(resultado)
resultado = a >= b
print(resultado)
resultado = a <= b
print(resultado)
resultado = a == b

# %% [markdown]
# #### Operadores Lógicos

# %% [markdown]
# ##### Operador E

# %%
# Operador AND
resultado = False and False
print(resultado)
resultado = True and False
print(resultado)
resultado = False and True
print(resultado)
resultado = True or True
print(resultado)

# %% [markdown]
# ##### Operador OU

# %%
resultado = False and False
print(resultado)
resultado = True and False
print(resultado)
resultado = False and True
print(resultado)
resultado = True or True
print(resultado)

# %% [markdown]
# ##### Lógica negação

# %%
resultado not(True)
print(resultado)

# %% [markdown]
# ### Entrada de Dados

# %% [markdown]
# Feito através do comando: input().

# %%
entrada = input("Digite um texto: ")
print(entrada)
print(type(entrada))
# Out:
# levich
# <class 'str'>

# %% [markdown]
# ### Conversão de dados em Python

# %%
entrada = int(input("Digite um valor: ")) # Para valores inteiros
print(entrada)
print(type(entrada))

# %%
entrada = float(input("Digite um valor: ")) # Para valores de ponto flutuante
print(entrada)
print(type(entrada))

# %% [markdown]
# #### Código 1 - Para revisão de python
#
# ##### Estrutura sequencial

# %% [markdown]
# 1. Fazer um aplicativo de terminal que leia um vaor inteiro correspondente à idade de uma pessoa em dias e informe-a e anos, meses e dias. Obs: Apenas para facilitar o cálculo, considere todo ano com 365 dias e todo mês com 30 dias. Nos casos de teste nunca averá uma situação que permite 12 meses e alguns dias como 360, 363, 364

# %%
# Código 1 - Idade em Anos, Meses e Dias

#---- Entrada de dados -------#
dias = int(input("Digite a quantidade de dias: "))

#----Processamento de dados-----#
anos = dias // 365 # Calculo para saber a quantidade de anos
meses = (dias % 365) // 30 # Meses
dias = (dias % 365) % 30 # Dias restantes

#----Saída de Dados----#
print(f"Você possui {anos} anos, {meses} meses e {dias} dias de vida.")

# %% [markdown]
# ### Estrutura de controle de código - DECISÃO
#
# #### IF ELIF ELSE

# %%
a = 2
b = 3
clodoaldo = a + b

if (clodoaldo == 5):
    print("Valor da variável clodoaldo é verdadeira")
print("Fim pogam!")
# Out:
# Valor da variável clodoaldo é verdadeira
# Fim pogama!

# %%
valor = input("Deseja continuar? (S/N): ")
if (valor.upper() == "S"):
    print("Acesso permitido")
else:
    print("Acesso negado")

# %%
valor = input("Deseja continuar? (S/N): ")
if (valor.upper() == "S"):
    print("Acesso permitido")
elif (valor.upper() == "N"):
    print("Acesso negado")
else:
    print("Digite S ou N")
# Out:
# Digite S ou N

# %% [markdown]
# #### match case

# %%
codigo = int(input("Digite um código de 1 a 5: "))

match (codigo):
    case 1:
        print("Clodoaldo")
    case 2:
        print("SENAI")
    case 3:
        print("Americana")
    case 4:
        print("Campeão")
    case 5:
        print(codigo)
    case _:
        print("Nenhum valor válido digitado")
print("Fim pogam!")
# Out:
# 5
# Fim pogam!

# %% [markdown]
# ### Estrutura de controle de repetição - Determinada

# %%
i = 0
print(i)
i = 1
print(i)
i = 2
print(i)
i = 3
print(i)

# %% [markdown]
# #### Exemplo 1

# %%
n = int(input("Digite um número de 1 a 10: "))

for i in range(0,10):
    print(f"{n} x {i + 1} = {n * (i+1)}")
# Out:
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120

# %% [markdown]
# #### Exemplo 2

# %%
# Entrada de Dados
n = int(input("Quantos números você vai digitar? R: "))
# Processamento de dados
for i in range(n):
    numero = int(input("Digite um número: "))
    # Verificar se é IMPAR ou PAR
    if numero < 0:
        print("NEGATIVO")
    elif numero > 0:
        print("POSITIVO")
    else:
        print("NULO")
        continue
    if (numero % 2 == 0):
        print("PAR")
    elif (numero % 2 != 0):
        print("IMPAR")

# %% [markdown]
# ### Estrutura de controle de repetição - Indeterminada

# %%
while (True):
    senha = input("Digite a senha: ")
    if (senha == "2014"):
        print("Acesso permitido!")
        break
    else:
        print("Acesso negado...")
# Out:
# Acesso negado
# Acesso permitido

# %% [markdown]
# #### Exemplo

# %%
while (True):
    print("Digite dois números: ")
    x = int(input())
    y = int(input())
    if x > y:
        print("Descrescente!")
    elif y > x:
        print("Crescente!")
    else:
        print("Iguais!")
        break

# %% [markdown]
# ## Coleções de dados em Python
#
# ### Lista
#  -> É uma coleção ordenada e mutável. Permite membros duplicados.

# %%
lista = ["Senai", False, 35, 1.73]

# %%
print(lista)
# Out:
# ['Senai', False, 35, 1.73]

# %%
print(lista[0])

# %%
print(type(lista))

# %%
del lista[1]
print(lista)

# %% [markdown]
# ### Dicionário
#  -> É uma coleção ordenada e mutável. Não permite membors duplicados. Cada item é um par chave-valor

# %%
dicionario = {"SENAI": "5.07", "AMERICANA": 10, "CLODOALDO": True}

# %%
print(dicionario["SENAI"])

# %%
for chave in dicionario.keys():
    print(chave, "->", dicionario[chave])

# %%
dicionario.update({"novo": "valor"})
print(dicionario)

# %% [markdown]
# #### Exemplo

# %%
produtos = {
    1 : 5.00,
    2 : 3.50,
    3 : 4.80,
    4 : 8.90,
    5 : 7.32
}

codigo = int(input("Digite o código do produto: "))
quantidade = int(input("Digite a quantidade de produto a ser comprada: "))
try:
    print(f"O valor total da compra é de {produtos[codigo] * quantidade}")
except KeyError:
    print("Valor inválido. Use 1 a 5.")
# Out:
# O valor total da compra é de 17.8

# %% [markdown]
# ### Funções em Python

# %% [markdown]
# > Reaproveita e modulariza o pedaços de código

# %%
def saida():
    print("SENAI AMERICANA")

# %%
saida()
# Out:
# SENAI AMERICANA

# %%
def mult(a, b):
    print(f"{a} x {b} = {a*b}")

# %%
mult(2,3)
# Out:
# 2 x 3 = 6

# %% [markdown]
# > Se os parâmetros da função possuirem um valor padrão definido, é possível chamá-la somente com um ou menos argumentos.

# %%
def deltaBhaskara(a,b,c):
    delta = (b * b) - (4*a*c)
    return delta

# %%
print(deltaBhaskara(1, -3, 2))
# Out:
# 1
